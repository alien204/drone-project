# %%
# !pip3 install djitellopy
# Out:
# Collecting djitellopy
#   Using cached djitellopy-2.4.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy in /Users/alien204/miniforge3/lib/python3.10/site-packages (from djitellopy) (1.24.1)
# Requirement already satisfied: opencv-python in /Users/alien204/miniforge3/lib/python3.10/site-packages (from djitellopy) (4.7.0.68)
# Installing collected packages: djitellopy
# Successfully installed djitellopy-2.4.0

# %%
from djitellopy import tello
import cv2

me = tello.Tello()
#cap = cv2.VideoCapture(0)
me.connect()
print(me.get_battery())
me.streamon()


while True:
    img = me.get_frame_read().frame
    img = cv2.resize(img, (360, 240))
    cv2.imshow("results", img)
    cv2.waitKey(1)
# Out:
# [INFO] tello.py - 122 - Tello instance was initialized. Host: '192.168.10.1'. Port: '8889'.
# [INFO] tello.py - 437 - Send command: 'command'
# [INFO] tello.py - 461 - Response command: 'ok'
# [INFO] tello.py - 437 - Send command: 'streamon'
# [INFO] tello.py - 461 - Response streamon: 'ok'
# 13
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] non-existing PPS 0 referenced
# [h264 @ 0x10680f600] decode_slice_header error
# [h264 @ 0x10680f600] no frame!
# [h264 @ 0x1068b1400] left block unavailable for requested intra mode
# [h264 @ 0x1068b1400] error while decoding MB 0 31, bytestream 0
# [h264 @ 0x10700a000] error while decoding MB 7 40, bytestream -6
# [h264 @ 0x10700de00] left block unavailable for requested intra mode
# [h264 @ 0x10700de00] error while decoding MB 0 39, bytestream 1540
# [h264 @ 0x106841000] left block unavailable for requested intra mode
# [h264 @ 0x106841000] error while decoding MB 0 39, bytestream 55
# [h264 @ 0x106841000] left block unavailable for requested intra mode
# [h264 @ 0x106841000] error while decoding MB 0 40, bytestream 1308
# [h264 @ 0x106841000] error while decoding MB 26 29, bytestream -5
# [h264 @ 0x10700a000] error while decoding MB 55 40, bytestream -7
# [h264 @ 0x106841000] left block unavailable for requested intra mode
# [h264 @ 0x106841000] error while decoding MB 0 43, bytestream 1033
# [h264 @ 0x107009a00] left block unavailable for requested intra mode
# [h264 @ 0x107009a00] error while decoding MB 0 30, bytestream 1572
# [h264 @ 0x1068b1400] error while decoding MB 59 39, bytestream -5
# [h264 @ 0x10700de00] error while decoding MB 43 44, bytestream -6
# [h264 @ 0x1068b0e00] error while decoding MB 19 41, bytestream -5
# [h264 @ 0x1068b1400] left block unavailable for requested intra mode
# [h264 @ 0x1068b1400] error while decoding MB 0 26, bytestream 2593
# [h264 @ 0x106841000] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x106841000] error while decoding MB 0 40, bytestream 1711
# [h264 @ 0x10700a000] left block unavailable for requested intra mode
# [h264 @ 0x10700a000] error while decoding MB 0 40, bytestream 9196
# [h264 @ 0x10700de00] left block unavailable for requested intra mode
# [h264 @ 0x10700de00] error while decoding MB 0 41, bytestream 205
# [h264 @ 0x10700a000] error while decoding MB 55 41, bytestream -5
# [h264 @ 0x1068b0e00] left block unavailable for requested intra mode
# [h264 @ 0x1068b0e00] error while decoding MB 0 41, bytestream 36
# [h264 @ 0x106841000] left block unavailable for requested intra mode
# [h264 @ 0x106841000] error while decoding MB 0 22, bytestream 362
# [h264 @ 0x106841000] left block unavailable for requested intra mode
# [h264 @ 0x106841000] error while decoding MB 0 33, bytestream 232
# [h264 @ 0x10700de00] error while decoding MB 58 39, bytestream -5
# [h264 @ 0x107009a00] error while decoding MB 7 41, bytestream -5
# [h264 @ 0x1068b0e00] error while decoding MB 28 41, bytestream 67
# [h264 @ 0x1068b1400] left block unavailable for requested intra mode
# [h264 @ 0x1068b1400] error while decoding MB 0 31, bytestream 0
# [h264 @ 0x1068b1400] left block unavailable for requested intra mode
# [h264 @ 0x1068b1400] error while decoding MB 0 40, bytestream 64
# [h264 @ 0x1068b0e00] error while decoding MB 33 32, bytestream -8
# [h264 @ 0x1068b1400] error while decoding MB 37 44, bytestream -6
# [h264 @ 0x106841000] left block unavailable for requested intra mode
# [h264 @ 0x106841000] error while decoding MB 0 19, bytestream 2105
# [h264 @ 0x1068b1400] error while decoding MB 5 40, bytestream -5
# [h264 @ 0x107009a00] error while decoding MB 30 40, bytestream -5
# [h264 @ 0x106841000] left block unavailable for requested intra mode
# [h264 @ 0x106841000] error while decoding MB 0 40, bytestream 1405
# [h264 @ 0x1068b0e00] left block unavailable for requested intra mode
# [h264 @ 0x1068b0e00] error while decoding MB 0 37, bytestream 109
# [h264 @ 0x107009a00] left block unavailable for requested intra mode
# [h264 @ 0x107009a00] error while decoding MB 0 40, bytestream 1059
# [h264 @ 0x106845600] error while decoding MB 6 40, bytestream -6
# [h264 @ 0x106845600] error while decoding MB 25 37, bytestream -6
# [h264 @ 0x106845600] left block unavailable for requested intra mode
# [h264 @ 0x106845600] error while decoding MB 0 40, bytestream 1555
# [h264 @ 0x106841000] error while decoding MB 16 28, bytestream -5
# [h264 @ 0x10700de00] left block unavailable for requested intra mode
# [h264 @ 0x10700de00] error while decoding MB 0 40, bytestream 3
# [h264 @ 0x1068b1400] left block unavailable for requested intra mode
# [h264 @ 0x1068b1400] error while decoding MB 0 40, bytestream 1532
# [h264 @ 0x1068b1400] error while decoding MB 37 40, bytestream -6
# [h264 @ 0x10700a000] error while decoding MB 36 39, bytestream -6
# [h264 @ 0x106845600] left block unavailable for requested intra mode
# [h264 @ 0x106845600] error while decoding MB 0 41, bytestream 1205
# [h264 @ 0x107010a00] error while decoding MB 26 42, bytestream -8
# [h264 @ 0x10700de00] left block unavailable for requested intra mode
# [h264 @ 0x10700de00] error while decoding MB 0 40, bytestream 1467
# [h264 @ 0x1068b1400] left block unavailable for requested intra mode
# [h264 @ 0x1068b1400] error while decoding MB 0 40, bytestream 175
# [h264 @ 0x1068b0e00] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x1068b0e00] error while decoding MB 0 17, bytestream 4694
# [h264 @ 0x107010a00] left block unavailable for requested intra mode
# [h264 @ 0x107010a00] error while decoding MB 0 41, bytestream 10185
# [h264 @ 0x107009a00] error while decoding MB 35 40, bytestream -5
# 1   HIToolbox                           0x00000001bb4705c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001bb470188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x00000001bb3dd8bc _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1184
# 4   HIToolbox                           0x00000001bb470004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 5   AppKit                              0x00000001b525fd1c -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 6   AppKit                              0x00000001b50f5928 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 7   CoreFoundation                      0x00000001b1d12560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 8   CoreFoundation                      0x00000001b1db0044 ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00000001b1daff8c _CFXRegistrationPost + 440
# 10  CoreFoundation                      0x00000001b1ce3b64 _CFXNotificationPost + 708
# 11  Foundation                          0x00000001b2bd338c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 12  AppKit                              0x00000001b52602a0 spacesNotificationHandler + 96
# 13  SkyLight                            0x00000001b694d214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 14  SkyLight                            0x00000001b694be10 CGSSnarfAndDispatchDatagrams + 808
# 15  SkyLight                            0x00000001b6c73a9c SLSGetNextEventRecordInternal + 344
# 16  SkyLight                            0x00000001b6a74fb0 SLEventCreateNextEvent + 16
# 17  HIToolbox                           0x00000001bb408b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 18  HIToolbox                           0x00000001bb408ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 19  CoreFoundation                      0x00000001b1d4d410 __CFMachPortPerform + 260
# 20  CoreFoundation                      0x00000001b1d1df98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 21  CoreFoundation                      0x00000001b1d1deb8 __CFRunLoopDoSource1 + 520
# 22  CoreFoundation                      0x00000001b1d1c8a4 __CFRunLoopRun + 2264
# 23  CoreFoundation                      0x00000001b1d1b878 CFRunLoopRunSpecific + 612
# 24  HIToolbox                           0x00000001bb3fbfa0 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x00000001bb3fbc30 ReceiveNextEventCommon + 236
# 26  HIToolbox                           0x00000001bb3fbb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 27  AppKit                              0x00000001b4fa1838 _DPSNextEvent + 632
# 28  AppKit                              0x00000001b4fa09c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 29  cv2.abi3.so                         0x0000000145814d3c cvWaitKey + 332
# 30  cv2.abi3.so                         0x000000014580eb50 _ZN2cv9waitKeyExEi + 224
# 31  cv2.abi3.so                         0x000000014580ec74 _ZN2cv7waitKeyEi + 48
# 32  cv2.abi3.so                         0x0000000144d62ad4 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  python3.10                          0x0000000102d78c88 cfunction_call + 80
# 34  python3.10                          0x0000000102d26294 _PyObject_MakeTpCall + 612
# 35  python3.10                          0x0000000102e150f0 call_function + 676
# 36  python3.10                          0x0000000102e10de8 _PyEval_EvalFrameDefault + 26388
# 37  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 38  python3.10                          0x0000000102e09590 PyEval_EvalCode + 120
# 39  python3.10                          0x0000000102e05108 builtin_exec + 836
# 40  python3.10                          0x0000000102d799e4 cfunction_vectorcall_FASTCALL + 200
# 41  python3.10                          0x0000000102e15058 call_function + 524
# 42  python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 43  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 44  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 45  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 46  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 47  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 48  python3.10                          0x0000000102d3f628 gen_send + 52
# 49  python3.10                          0x0000000102d338d0 method_vectorcall_O + 152
# 50  python3.10                          0x0000000102e15058 call_function + 524
# 51  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 52  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 53  python3.10                          0x0000000102e15058 call_function + 524
# 54  python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 55  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 56  python3.10                          0x0000000102e15058 call_function + 524
# 57  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 58  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 59  python3.10                          0x0000000102d2994c method_vectorcall + 164
# 60  python3.10                          0x0000000102d26ad8 PyVectorcall_Call + 156
# 61  python3.10                          0x0000000102e11160 _PyEval_EvalFrameDefault + 27276
# 62  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 63  python3.10                          0x0000000102d2994c method_vectorcall + 164
# 64  python3.10                          0x0000000102e15058 call_function + 524
# 65  python3.10                          0x0000000102e10ec8 _PyEval_EvalFrameDefault + 26612
# 66  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 67  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 68  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 69  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 70  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 71  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 72  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 73  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 74  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 75  _asyncio.cpython-310-darwin.so      0x000000010386ff8c task_step + 548
# 76  _asyncio.cpython-310-darwin.so      0x0000000103870cf0 task_wakeup + 136
# 77  python3.10                          0x0000000102d79650 cfunction_vectorcall_O + 252
# 78  python3.10                          0x0000000102e2db78 context_run + 348
# 79  python3.10                          0x0000000102d798a8 cfunction_vectorcall_FASTCALL_KEYWORDS + 112
# 80  python3.10                          0x0000000102e11160 _PyEval_EvalFrameDefault + 27276
# 81  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 82  python3.10                          0x0000000102e15058 call_function + 524
# 83  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 84  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 85  python3.10                          0x0000000102e15058 call_function + 524
# 86  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 87  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 88  python3.10                          0x0000000102e15058 call_function + 524
# 89  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 90  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 91  python3.10                          0x0000000102e15058 call_function + 524
# 92  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 93  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 94  python3.10                          0x0000000102e15058 call_function + 524
# 95  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 96  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 97  python3.10                          0x0000000102d2994c method_vectorcall + 164
# 98  python3.10                          0x0000000102e15058 call_function + 524
# 99  python3.10                          0x0000000102e10de8 _PyEval_EvalFrameDefault + 26388
# 100 python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 101 python3.10                          0x0000000102e09590 PyEval_EvalCode + 120
# 102 python3.10                          0x0000000102e05108 builtin_exec + 836
# 103 python3.10                          0x0000000102d799e4 cfunction_vectorcall_FASTCALL + 200
# 104 python3.10                          0x0000000102e15058 call_function + 524
# 105 python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 106 python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 107 python3.10                          0x0000000102e15058 call_function + 524
# 108 python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 109 python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 110 python3.10                          0x0000000102e89164 pymain_run_module + 272
# 111 python3.10                          0x0000000102e887a0 Py_RunMain + 1584
# 112 python3.10                          0x0000000102e89c50 pymain_main + 1272
# 113 python3.10                          0x0000000102cd000c main + 56
# 114 dyld                                0x00000001b1913e50 start + 2544
# [h264 @ 0x1068b0e00] error while decoding MB 36 35, bytestream -5
# 1   HIToolbox                           0x00000001bb3fb90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x00000001bb43a478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x00000001b694d214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x00000001b694be10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x00000001b6c73a9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x00000001b6a74fb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x00000001bb408b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x00000001bb408ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x00000001b1d4d410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x00000001b1d1df98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x00000001b1d1deb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001b1d1c8a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x00000001b1d1b878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x00000001bb3fbfa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00000001bb3fbc30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x00000001bb3fbb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x00000001b4fa1838 _DPSNextEvent + 632
# 18  AppKit                              0x00000001b4fa09c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x0000000145814d3c cvWaitKey + 332
# 20  cv2.abi3.so                         0x000000014580eb50 _ZN2cv9waitKeyExEi + 224
# 21  cv2.abi3.so                         0x000000014580ec74 _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x0000000144d62ad4 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.10                          0x0000000102d78c88 cfunction_call + 80
# 24  python3.10                          0x0000000102d26294 _PyObject_MakeTpCall + 612
# 25  python3.10                          0x0000000102e150f0 call_function + 676
# 26  python3.10                          0x0000000102e10de8 _PyEval_EvalFrameDefault + 26388
# 27  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 28  python3.10                          0x0000000102e09590 PyEval_EvalCode + 120
# 29  python3.10                          0x0000000102e05108 builtin_exec + 836
# 30  python3.10                          0x0000000102d799e4 cfunction_vectorcall_FASTCALL + 200
# 31  python3.10                          0x0000000102e15058 call_function + 524
# 32  python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 33  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 34  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 35  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 36  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 37  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 38  python3.10                          0x0000000102d3f628 gen_send + 52
# 39  python3.10                          0x0000000102d338d0 method_vectorcall_O + 152
# 40  python3.10                          0x0000000102e15058 call_function + 524
# 41  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 42  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 43  python3.10                          0x0000000102e15058 call_function + 524
# 44  python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 45  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 46  python3.10                          0x0000000102e15058 call_function + 524
# 47  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 48  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 49  python3.10                          0x0000000102d2994c method_vectorcall + 164
# 50  python3.10                          0x0000000102d26ad8 PyVectorcall_Call + 156
# 51  python3.10                          0x0000000102e11160 _PyEval_EvalFrameDefault + 27276
# 52  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 53  python3.10                          0x0000000102d2994c method_vectorcall + 164
# 54  python3.10                          0x0000000102e15058 call_function + 524
# 55  python3.10                          0x0000000102e10ec8 _PyEval_EvalFrameDefault + 26612
# 56  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 57  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 58  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 59  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 60  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 61  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 62  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 63  python3.10                          0x0000000102e0cfdc _PyEval_EvalFrameDefault + 10504
# 64  python3.10                          0x0000000102d3f054 gen_send_ex2 + 516
# 65  _asyncio.cpython-310-darwin.so      0x000000010386ff8c task_step + 548
# 66  _asyncio.cpython-310-darwin.so      0x0000000103870cf0 task_wakeup + 136
# 67  python3.10                          0x0000000102d79650 cfunction_vectorcall_O + 252
# 68  python3.10                          0x0000000102e2db78 context_run + 348
# 69  python3.10                          0x0000000102d798a8 cfunction_vectorcall_FASTCALL_KEYWORDS + 112
# 70  python3.10                          0x0000000102e11160 _PyEval_EvalFrameDefault + 27276
# 71  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 72  python3.10                          0x0000000102e15058 call_function + 524
# 73  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 74  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 75  python3.10                          0x0000000102e15058 call_function + 524
# 76  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 77  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 78  python3.10                          0x0000000102e15058 call_function + 524
# 79  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 80  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 81  python3.10                          0x0000000102e15058 call_function + 524
# 82  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 83  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 84  python3.10                          0x0000000102e15058 call_function + 524
# 85  python3.10                          0x0000000102e10dc0 _PyEval_EvalFrameDefault + 26348
# 86  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 87  python3.10                          0x0000000102d2994c method_vectorcall + 164
# 88  python3.10                          0x0000000102e15058 call_function + 524
# 89  python3.10                          0x0000000102e10de8 _PyEval_EvalFrameDefault + 26388
# 90  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 91  python3.10                          0x0000000102e09590 PyEval_EvalCode + 120
# 92  python3.10                          0x0000000102e05108 builtin_exec + 836
# 93  python3.10                          0x0000000102d799e4 cfunction_vectorcall_FASTCALL + 200
# 94  python3.10                          0x0000000102e15058 call_function + 524
# 95  python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 96  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 97  python3.10                          0x0000000102e15058 call_function + 524
# 98  python3.10                          0x0000000102e10e58 _PyEval_EvalFrameDefault + 26500
# 99  python3.10                          0x0000000102e09dc8 _PyEval_Vector + 2056
# 100 python3.10                          0x0000000102e89164 pymain_run_module + 272
# 101 python3.10                          0x0000000102e887a0 Py_RunMain + 1584
# 102 python3.10                          0x0000000102e89c50 pymain_main + 1272
# 103 python3.10                          0x0000000102cd000c main + 56
# 104 dyld                                0x00000001b1913e50 start + 2544
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# [h264 @ 0x107010a00] error while decoding MB 57 19, bytestream -6
# Exception in thread Thread-7 (update_frame):
# Traceback (most recent call last):
#   File "/Users/alien204/miniforge3/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/Users/alien204/miniforge3/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alien204/miniforge3/lib/python3.10/site-packages/djitellopy/tello.py", line 1065, in update_frame
#     self.stop()
#   File "/Users/alien204/miniforge3/lib/python3.10/site-packages/djitellopy/tello.py", line 1074, in stop
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 13
#      11 while True:
#      12     img = me.get_frame_read().frame
# ---> 13     img = cv2.resize(img, (360, 240))
#      14     cv2.imshow("results", img)
#      15     cv2.waitKey(1)
#
# error: OpenCV(4.7.0) /Users/opencv-cn/GHA-OCV-1/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#     self.worker.join()
#   File "/Users/alien204/miniforge3/lib/python3.10/threading.py", line 1093, in join
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread

# %%
import cv2 
import numpy as np
from keras.models import load_model

# Load the model
model = load_model('keras_model.h5')

# CAMERA can be 0 or 1 based on default camera of your computer.
camera = cv2.VideoCapture('V_318.mp4_frame4.jpg')

# Grab the labels from the labels.txt file. This will be used later.
labels = open('labels.txt', 'r').readlines()

while True:
    # Grab the webcameras image.
    ret, image = camera.read()
    # Resize the raw image into (224-height,224-width) pixels.
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
    # Show the image in a window
    cv2.imshow('Webcam Image', image)
    # Make the image a numpy array and reshape it to the models input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)
    # Normalize the image array
    image = (image / 127.5) - 1
    # Have the model predict what the current image is. Model.predict
    # returns an array of percentages. Example:[0.2,0.8] meaning its 20% sure
    # it is the first label and 80% sure its the second label.
    probabilities = model.predict(image)
    # Print what the highest value probabilitie label
    print(labels[np.argmax(probabilities)])
    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)
    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# Metal device set to: Apple M1 Pro
# 2023-01-24 19:25:47.216170: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-24 19:25:47.216188: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2023-01-24 19:25:48.492199: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-01-24 19:25:48.650455: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 482ms/step
# 0 violence
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 18
#      16 ret, image = camera.read()
#      17 # Resize the raw image into (224-height,224-width) pixels.
# ---> 18 image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
#      19 # Show the image in a window
#      20 cv2.imshow('Webcam Image', image)
#
# error: OpenCV(4.7.0) /Users/opencv-cn/GHA-OCV-1/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
